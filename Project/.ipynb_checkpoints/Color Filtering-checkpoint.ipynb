# %%
# %matplotlib inline

import cv2
import sys
from matplotlib import pyplot as plt
from matplotlib import colors as mcolors
from matplotlib import image as mpimg

import numpy as np
import matplotlib
import numpy as pillow
from PIL import Image #Python Imaging Library(PIL)
from skimage.io import imread

# %%
image = imread('rose.jpg');
plt.imshow(image)

# %%
titles = ['Penguin', 'Red channel', 'Green channel', 'Blue channel']
cmaps = [None, plt.cm.Reds_r, plt.cm.Greens_r, plt.cm.Blues_r]

fig, axes = plt.subplots(1, 4, figsize=(13,13))
objs = zip(axes, (image, *image.transpose(2,0,1)), titles, cmaps)

for ax, channel, title, cmap in objs:
    ax.imshow(channel, cmap=cmap)
    ax.set_title(title)
    ax.set_xticks(())
    ax.set_yticks(())

plt.savefig('RGB1.png')

# %%
titles = ['Penguin', 'Red channel', 'Green channel', 'Blue channel']
cmaps = [None, plt.cm.Reds_r, plt.cm.Greens_r, plt.cm.Blues_r]

fig, axes = plt.subplots(1, 1, figsize=(13,13))
#objs = zip((image, *image.transpose(2,0,1)), titles, cmaps)

for channel, title, cmap in objs:
    axes.imshow(channel, cmap=cmap)
    axes.set_title(title)
    axes.set_xticks(())
    axes.set_yticks(())

plt.savefig('RGB1.png')

# %%
image = plt.imread('rose.jpg')

titles = ['Rose']
cmaps = [None]

fig, axes = plt.subplots(1, 1, figsize=(13,13))
objs = zip(axes, (image, *image.transpose(2,0,1)), titles, cmaps)

for ax, channel, title, cmap in objs:
    ax.imshow(channel, cmap=cmap)
    ax.set_title(title)
    ax.set_xticks(())
    ax.set_yticks(())

plt.savefig('RGB1.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-80d44414f929> in <module>
#       5
#       6 fig, axes = plt.subplots(1, 1, figsize=(13,13))
# ----> 7 objs = zip(axes, (image, *image.transpose(2,0,1)), titles, cmaps)
#       8
#       9 for ax, channel, title, cmap in objs:
#
# TypeError: zip argument #1 must support iteration

# %%
fig = plt.figure()
a = fig.add_subplot(1,2,1)
imgplot = plt.imshow('rose.jpg')
a.set_title('Before')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
a = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow('rose.jpg')
imgplot.set_clim(0.0, 0.7)
a.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d62fcd6d71ee> in <module>
#       1 fig = plt.figure()
#       2 a = fig.add_subplot(1,2,1)
# ----> 3 imgplot = plt.imshow('rose.jpg')
#       4 a.set_title('Before')
#       5 plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
#
# ~\Anaconda3-new\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# ~\Anaconda3-new\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
