# %%
import cv2
import sys
from matplotlib import pyplot as plt 
import numpy as np
from PIL import Image 
from skimage.io import imread
#from skimage.util import random_noise

# %%
image = imread('Sunflower.jpg');
#img = cv2.imread('./Sunflower.jpg',0)
plt.imshow(image)

# %%
def grayscale(rgb):
    B = rgb[:,:,0]
    G = rgb[:,:,1]
    R = rgb[:,:,2]
    gray = 0.2989*R + 0.5870*G + 0.1140*B
    
    return gray

# %%
greyImg = grayscale(image);
plt.imshow(greyImg)

# %%
#I = np.zeros(image.shape, np.uint8)
#mean = 0
#sigma = 1
#cv2.randn(I, mean, sigma) #generates random noise distribution
#noisyImg = cv2.add(greyImg,I) #adds noise to the original image
#plt.imshow(noisyImg)

def noise(image):
    row,col= image.shape
    mean = 0
    var = 0.1
    sigma = var ** 0.5
    gaussian = np.random.normal(mean,sigma,(row,col))
    gaussian = gaussian.reshape(row,col)
    noise = image + gaussian
    
    return noise

# %%
newI = noise(greyImg);
plt.imshow(newI)
