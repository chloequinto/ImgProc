# %% [markdown]
# Higher Contrast My HW

# %%
import cv2 
import numpy as np
import matplotlib
from pylab import *
from scipy.signal import convolve2d
from scipy.misc import imfilter

# %%
img = cv2.imread('hw.jpg')
imshow(img, aspect='auto')

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])

# %%
cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

# %%
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.show()

# %%
cdf_m = np.ma.masked_equal(cdf,255)
cdf_m = (cdf_m - cdf_m.min())*255/(cdf_m.max()-cdf_m.min())
cdf = np.ma.filled(cdf_m,0).astype('uint8')

# %%
img = img + 10

# %%
img2 = cdf[img]

# %%
imshow(img2)
title('New Image')
# Out:
# Text(0.5, 1.0, 'New Image')

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(img)
ax[0].set_title("Original")
ax[1].imshow(img2, cmap="gray")
ax[1].set_title("High Contrast")
# Out:
# Text(0.5, 1.0, 'High Contrast')

# %%
cv2.imwrite("out.jpg", img2)
# Out:
# True

# %%
img = cv2.GaussianBlur(img2,(3,3),0)
imshow(img)

# %%
filter2 = cv2.Laplacian(img,cv2.CV_64F)

# %%
img0 = cv2.imread('out.jpg')

# %%
#img0 = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)

# %%
img = cv2.GaussianBlur(img0,(3,3),0)

# %%
laplacian = cv2.Laplacian(img,cv2.CV_64F)

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
imshow(img3)

# %%
fig, ax = plt.subplots(1,2,3)
ax[0].imshow(img2)
ax[0].set_title("Original")
ax[1].imshow(img3)
ax[1].set_title("High Contrast")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-250-2d7ca4ed4e7b> in <module>
# ----> 1 fig, ax = plt.subplots(1,2,3)
#       2 ax[0].imshow(img2)
#       3 ax[0].set_title("Original")
#       4 ax[1].imshow(img3)
#       5 ax[1].set_title("High Contrast")
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1218     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1219                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1220                        gridspec_kw=gridspec_kw)
#    1221     return fig, axs
#    1222
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1500
# ...

# %%
cv2.imwrite("out2.jpg", img2)
# Out:
# True
